# %% [markdown]
# # MLB Player Stats - 1961 - 2019
#
# **Data Source:** https://www.fangraphs.com/leaders.aspx?pos=all&stats=rel&lg=all&qual=y&type=8&season=2019&month=0&season1=2019&ind=0&team=0&rost=0&age=0&filter=&players=0&startdate=2019-01-01&enddate=2019-12-31<br>
#
# ---

# %%
import numpy as np
import pandas as pd
import mlbgame

# %% [markdown]
# ## Purpose
# Create dataset of MLB relievers from 1961 to 2019.

# %% [markdown]
# ### Convert Batting Data from Excel to Pandas

# %%
# Load each year of interest
raw61 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1961.csv', index_col=0)
raw61['Year'] = 1961
raw62 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1962.csv', index_col=0)
raw62['Year'] = 1962
raw63 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1963.csv', index_col=0)
raw63['Year'] = 1963
raw64 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1964.csv', index_col=0)
raw64['Year'] = 1964
raw65 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1965.csv', index_col=0)
raw65['Year'] = 1965
raw66 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1966.csv', index_col=0)
raw66['Year'] = 1966
raw67 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1967.csv', index_col=0)
raw67['Year'] = 1967
raw68 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1968.csv', index_col=0)
raw68['Year'] = 1968
raw69 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1969.csv', index_col=0)
raw69['Year'] = 1969
raw70 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1970.csv', index_col=0)
raw70['Year'] = 1970
raw71 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1971.csv', index_col=0)
raw71['Year'] = 1971
raw72 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1972.csv', index_col=0)
raw72['Year'] = 1972
raw73 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1973.csv', index_col=0)
raw73['Year'] = 1973
raw74 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1974.csv', index_col=0)
raw74['Year'] = 1974
raw75 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1975.csv', index_col=0)
raw75['Year'] = 1975
raw76 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1976.csv', index_col=0)
raw76['Year'] = 1976
raw77 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1977.csv', index_col=0)
raw77['Year'] = 1977
raw78 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1978.csv', index_col=0)
raw78['Year'] = 1978
raw79 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1979.csv', index_col=0)
raw79['Year'] = 1979
raw80 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1980.csv', index_col=0)
raw80['Year'] = 1980
raw81 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1981.csv', index_col=0)
raw81['Year'] = 1981
raw82 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1982.csv', index_col=0)
raw82['Year'] = 1982
raw83 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1983.csv', index_col=0)
raw83['Year'] = 1983
raw84 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1984.csv', index_col=0)
raw84['Year'] = 1984
raw85 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1985.csv', index_col=0)
raw85['Year'] = 1985
raw86 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1986.csv', index_col=0)
raw86['Year'] = 1986
raw87 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1987.csv', index_col=0)
raw87['Year'] = 1987
raw88 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1988.csv', index_col=0)
raw88['Year'] = 1988
raw89 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1989.csv', index_col=0)
raw89['Year'] = 1989
raw90 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1990.csv', index_col=0)
raw90['Year'] = 1990
raw91 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1991.csv', index_col=0)
raw91['Year'] = 1991
raw92 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1992.csv', index_col=0)
raw92['Year'] = 1992
raw93 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1993.csv', index_col=0)
raw93['Year'] = 1993
raw94 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1994.csv', index_col=0)
raw94['Year'] = 1994
raw95 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1995.csv', index_col=0)
raw95['Year'] = 1995
raw96 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1996.csv', index_col=0)
raw96['Year'] = 1996
raw97 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1997.csv', index_col=0)
raw97['Year'] = 1997
raw98 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1998.csv', index_col=0)
raw98['Year'] = 1998
raw99 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 1999.csv', index_col=0)
raw99['Year'] = 1999
raw00 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2000.csv', index_col=0)
raw00['Year'] = 2000
raw01 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2001.csv', index_col=0)
raw01['Year'] = 2001
raw02 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2002.csv', index_col=0)
raw02['Year'] = 2002
raw03 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2003.csv', index_col=0)
raw03['Year'] = 2003
raw04 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2004.csv', index_col=0)
raw04['Year'] = 2004
raw05 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2005.csv', index_col=0)
raw05['Year'] = 2005
raw06 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2006.csv', index_col=0)
raw06['Year'] = 2006
raw07 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2007.csv', index_col=0)
raw07['Year'] = 2007
raw08 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2008.csv', index_col=0)
raw08['Year'] = 2008
raw09 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2009.csv', index_col=0)
raw09['Year'] = 2009
raw10 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2010.csv', index_col=0)
raw10['Year'] = 2010
raw11 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2011.csv', index_col=0)
raw11['Year'] = 2011
raw12 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2012.csv', index_col=0)
raw12['Year'] = 2012
raw13 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2013.csv', index_col=0)
raw13['Year'] = 2013
raw14 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2014.csv', index_col=0)
raw14['Year'] = 2014
raw15 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2015.csv', index_col=0)
raw15['Year'] = 2015
raw16 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2016.csv', index_col=0)
raw16['Year'] = 2016
raw17 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2017.csv', index_col=0)
raw17['Year'] = 2017
raw18 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2018.csv', index_col=0)
raw18['Year'] = 2018
raw19 = pd.read_csv(r'C:\Users\brian\OneDrive\Projects\Baseball\Data\FanGraphs\Relief_Pitching_Data\FanGraphs Relief Pitchers - 2019.csv', index_col=0)
raw19['Year'] = 2019

raw_relief = pd.concat([raw61, raw62, raw63, raw64, raw65, raw66, raw67, raw68, raw69, raw70,
                           raw71, raw72, raw73, raw74, raw75, raw76, raw77, raw78, raw79, raw80,
                           raw81, raw82, raw83, raw84, raw85, raw86, raw87, raw88, raw89, raw90,
                           raw91, raw92, raw93, raw94, raw95, raw96, raw97, raw98, raw99, raw00,
                           raw01, raw02, raw03, raw04, raw05, raw06, raw07, raw08, raw09, raw10,
                           raw11, raw12, raw13, raw14, raw15, raw16, raw17, raw18, raw19], 
                           ignore_index=False, axis=0)

print(raw_relief.shape)
raw_relief.head()
# Out:
# (1566, 330)
#            Age   W   L   ERA    G  GS  CG  ShO  SV  BS  ...  LA  Barrels  \
# Team                                                    ...
# Orioles     29  15   9  3.00  108   2   0    0  22 NaN  ... NaN      NaN
# Yankees     28  19  10  3.32  130   3   0    0  32 NaN  ... NaN      NaN
# Giants      26  25  16  3.50  174  11   2    0  27 NaN  ... NaN      NaN
# Tigers      27  19  12  3.69  183   5   1    0  26 NaN  ... NaN      NaN
# White Sox   30  20  17  3.70  196   5   0    0  24 NaN  ... NaN      NaN
#
#            Barrel%  maxEV  HardHit  HardHit%  Events  Year  #NAME?  #NAME?.1
# Team
# Orioles        NaN    NaN      NaN       NaN       0  1961     NaN       NaN
# Yankees        NaN    NaN      NaN       NaN       0  1961     NaN       NaN
# Giants         NaN    NaN      NaN       NaN       0  1961     NaN       NaN
# Tigers         NaN    NaN      NaN       NaN       0  1961     NaN       NaN
# ...

# %%
# Export to CSV
raw_relief.to_csv('MLB_Relievers_1961-2019.csv', header=True)

# %%
df_relief_other_vars = raw_relief.copy()

df_relief_other_vars['K%'] = np.round( (df_relief_other_vars['SO'] / df_relief_other_vars['TBF']), 3)
df_relief_other_vars['BB%'] = np.round( (df_relief_other_vars['BB'] / df_relief_other_vars['TBF']), 3)

# Use FIP_IPs as has been adjusted to account for sum  up to team level (only .1 or .2 can be the decimals)
df_relief_other_vars['ERA'] = np.round( ((df_relief_other_vars['ER'] / df_relief_other_vars['IP']) * 9), 2)

# Baseball Reference has BF = AB + BB + HBP + SF 
df_relief_other_vars['BAbip'] = np.round( (df_relief_other_vars['H'] - df_relief_other_vars['HR']) / (
                                      df_relief_other_vars['TBF'] - df_relief_other_vars['BB'] -
                                      df_relief_other_vars['HBP'] - df_relief_other_vars['SO'] -
                                      df_relief_other_vars['HR']), 3)

# Baseball Reference has BF = AB + BB + HBP + SF 
df_relief_other_vars['OBP'] = np.round( (df_relief_other_vars['H'] + df_relief_other_vars['BB'] +
                                      df_relief_other_vars['HBP']) / (df_relief_other_vars['TBF']), 3)

df_relief_other_vars['SHO_per_BF'] = df_relief_other_vars['ShO'] / df_relief_other_vars['TBF']
df_relief_other_vars['CG_per_BF'] = df_relief_other_vars['CG'] / df_relief_other_vars['TBF']

# Take Tm out of the index and make it a column
df_relief_other_vars.reset_index(level=0, inplace=True)

df_relief_other_vars[['Year', 'Team', 'SO', 'BB', 'TBF', 'IP', 'FIP', 'K%', 'BB%', 'ERA', 'BAbip', 'OBP', 'SHO_per_BF', 'CG_per_BF']]
# Out:
#       Year       Team   SO   BB   TBF     IP   FIP     K%    BB%   ERA  BAbip  \
# 0     1961    Orioles  156   84   882  210.1  3.19  0.177  0.095  3.00  0.257
# 1     1961    Yankees  151  125   956  224.2  3.73  0.158  0.131  3.33  0.251
# 2     1961     Giants  255  163  1539  362.1  3.96  0.166  0.106  3.50  0.249
# 3     1961     Tigers  166  144  1226  273.0  4.66  0.135  0.117  3.69  0.273
# 4     1961  White Sox  195  109  1518  362.2  3.81  0.128  0.072  3.70  0.263
# ...    ...        ...  ...  ...   ...    ...   ...    ...    ...   ...    ...
# 1561  2019       Mets  556  227  2288  519.2  4.71  0.243  0.099  4.99  0.312
# 1562  2019     Royals  543  270  2539  565.0  4.55  0.214  0.106  5.07  0.324
# 1563  2019    Rockies  563  266  2685  606.1  5.12  0.210  0.099  5.18  0.300
# 1564  2019  Nationals  501  219  2232  500.2  4.94  0.224  0.098  5.69  0.311
# 1565  2019    Orioles  625  295  2936  654.0  5.38  0.213  0.100  5.79  0.309
#
# ...

# %%
# Reorder columns to match CombineRetroandBR.ipynb
df_relief_final_features = df_relief_other_vars[['Year', 'Team', 'FIP', 'K%', 'BB%', 'ERA', 'BAbip', 'OBP', 'CG_per_BF', 'SHO_per_BF']]

# Adjust team names to match Baseball Reference
df_relief_final_features.loc[(df_relief_final_features.Year <= 1965) & (df_relief_final_features.Team == 'Braves'), "Team"] = 'MLN'
df_relief_final_features.loc[(df_relief_final_features.Year <= 1967) & (df_relief_final_features.Team == 'Athletics'), "Team"] = 'KCA'

teams_dict = {'Tigers':'DET', 'Cardinals':'STL', 'Giants':'SFG', 'White Sox':'CHW', 'Athletics':'OAK',
              'Dodgers':'LAD', 'Yankees':'NYY', 'Braves':'ATL', 'Reds':'CIN',
             'Phillies':'PHI', 'Angels':'ANA', 'Cubs':'CHC', 'Twins':'MIN', 
              'Indians':'CLE', 'Red Sox':'BOS', 'Orioles':'BAL', 'Pirates':'PIT', 
              'Mets':'NYM', 'Astros':'HOU', 'Padres':'SDP', 'Royals':'KCR',
             'Brewers':'MIL', 'Rangers':'TEX', 'Mariners':'SEA', 'Blue Jays':'TOR',
             'Expos':'MON', 'Rockies':'COL', 'Marlins':'MIA', 'Diamondbacks':'ARI', 
             'Nationals':'WAS', 'Rays':'TBR', 'Senators':'WSA', 'Devil Rays':'TBR',
             'Colt .45\'s':'HOU', 'Pilots':'SEP'}

df_relief_final_features = df_relief_final_features.replace({'Team':teams_dict})
# print(df_relief_final_features['Team'].value_counts())

df_relief_final_features = df_relief_final_features.rename(columns={'Year': 'Year_relievers', 'Team': 'Team_relievers', 
                                                                    'FIP': 'FIP_relievers', 'K%': 'K%_relievers',
                                                                    'BB%': 'BB%_relievers', 'ERA': 'ERA_relievers', 
                                                                    'BAbip': 'BAbip_relievers', 'OBP': 'OBP_relievers',
                                                                    'CG_per_BF': 'CG_per_BF_relievers', 
                                                                    'SHO_per_BF': 'SHO_per_BF_relievers'})

print(df_relief_final_features.info(verbose=True))

# Export to CSV
df_relief_final_features.to_csv('Team_Name_Update_Relievers_1961-2019.csv', header=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1566 entries, 0 to 1565
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year_relievers        1566 non-null   int64
#  1   Team_relievers        1566 non-null   object
#  2   FIP_relievers         1566 non-null   float64
#  3   K%_relievers          1566 non-null   float64
#  4   BB%_relievers         1566 non-null   float64
#  5   ERA_relievers         1566 non-null   float64
#  6   BAbip_relievers       1566 non-null   float64
#  7   OBP_relievers         1566 non-null   float64
#  8   CG_per_BF_relievers   1566 non-null   float64
#  9   SHO_per_BF_relievers  1566 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 122.5+ KB
# None
